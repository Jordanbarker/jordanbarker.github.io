# %% [markdown]
# ## Table of contents:
# * [First Bullet Header2](#first-bullet2)
# * [Second Bullet Header2](#second-bullet2)

# %% [markdown]
# # [Discrete](#first-bullet2)

# %% [markdown]
# ### Bernoulli(p)
# Binary, boolean output: 1 (success) with probability p, or 0 (failure) with probability q=1-p.
# *  E[X]=p
# *  Var(X)=pq

# %%
import numpy as np
import matplotlib.pyplot as plt

p = 0.7 # probability of getting a "success" (heads)
num_trials = 1000

# generate random bernoulli distributed variables (0 or 1)
trials = np.random.binomial(n=1, p=p, size=num_trials)

# count the number of successes and failures
successes = np.count_nonzero(trials == 1)
failures = np.count_nonzero(trials == 0)
print(f'Successes: {successes}, Failures: {failures}')

labels = ['Successes', 'Failures']
counts = [successes, failures]
plt.bar(labels, counts, color=['blue', 'red'])
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.title('Bernoulli Distribution Simulation')
plt.show()
# Out:
# Successes: 714, Failures: 286

# %% [markdown]
# ### Binomial
# (n,p), f(y)=( nk )Pyqn-y where y=# of successes. E[Y]=np, Var(Y)=npq

# %% [markdown]
# ### Geometric(p)
# f(x)=(1-p)k-1p | F(x)=1-(1-p)k where x=1,2,.. # of Bern trials until success, FFFS implies x=4 and p is the success probability.  E[X]=1/p, Var(X)=q/p^2
#
# ### NegBin(r,p)
# sum of r Geom RV’s the time until the rth success. FFFSSFS = NegBin(3,p)=7
# f(y)=( k+r-1k)qy-rpr where y=r, r+1...
# E[Y]=r/p, Var(X)=qr/p^2
#
# ### Poisson(ƛ)
# f(x)=ƛxe-ƛ/x!  F(x)=e-ƛ ∑xi=0 ƛi/i!
# E[X] =ƛ=Var(X)
# Eg. Pois(12), What is the prob of exactly 8?
#    (use pmf) 128*e-12/8! =6.55%

# %% [markdown]
# # Continuous
# # [Continuous](#second-bullet2)
