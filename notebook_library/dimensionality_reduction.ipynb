# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

plt.rcParams['figure.figsize'] = (12, 4)
rng = np.random.default_rng(42)

x = np.linspace(0, 10, 100)
data = {'x': x}
for i in range(10):
    data[i] = np.sin(x) + rng.normal(1, 0.1, len(x))
    plt.plot(x, data[i])
    data[i+10] = np.cos(x) + rng.normal(1, 0.1, len(x))
    plt.plot(x, data[i+10])

df = pd.DataFrame(data)
plt.title('Multiple Time Series')
plt.ylabel('y')
plt.xlabel('x')
plt.legend()
plt.show()
# Out:
# C:\Users\JBarker\AppData\Local\Temp\ipykernel_18448\3243505097.py:22: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
